# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
# device = "cuda" # the device to load the model onto
# os.environ['CURL_CA_BUNDLE'] = './huggingface.co.crt'
# export HF_HUB_DOWNLOAD_TIMEOUT=30
# os.environ['HF_HUB_DOWNLOAD_TIMEOUT'] = '30'
# from transformers import GPT2Tokenizer, GPT2Model
# model = GPT2Model.from_pretrained('gpt2')
# import os
# # os.environ['CURL_CA_BUNDLE'] = ''
# import os
# os.environ['HTTP_PROXY'] = 'http://127.0.0.1:22'
# os.environ['HTTPS_PROXY'] = 'http://127.0.0.1:22'
# model = AutoModelForCausalLM.from_pretrained("alignment-handbook/zephyr-7b-sft-full", resume_download=True, trust_remote_code=True)

model_name = "alignment-handbook/zephyr-7b-sft-full"

model = AutoModelForCausalLM.from_pretrained("model_name")
# Out:
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/urllib3/connection.py:174, in _new_conn(self)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/urllib3/connectionpool.py:716, in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705     raise
#     707 except (
#     708     TimeoutError,
#     709     HTTPException,
#     710     SocketError,
#     711     ProtocolError,
#     712     BaseSSLError,
#     713     SSLError,
#     714     CertificateError,
#     715 ) as e:
# --> 716     # Discard the connection for these exceptions. It will be
#     717     # replaced during the next _get_conn() call.
#     718     clean_exit = False
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/urllib3/connectionpool.py:404, in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     398 if getattr(conn, "sock", None):
#     399     # In Python 3 socket.py will catch EAGAIN and return None when you
#     400     # try and read into the file pointer created by http.client, which
#     401     # instead raises a BadStatusLine exception. Instead of catching
#     402     # the exception and assuming all BadStatusLine exceptions are read
#     403     # timeouts, check for a zero timeout before making the request.
# --> 404     if read_timeout == 0:
#     405         raise ReadTimeoutError(
#     406             self, url, "Read timed out. (read timeout=%s)" % read_timeout
#     407         )
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/urllib3/connectionpool.py:1061, in _validate_conn(self, conn)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/urllib3/connection.py:363, in connect(self)
#     360     context.load_default_certs()
#     362 self.sock = ssl_wrap_socket(
# --> 363     sock=conn,
#     364     keyfile=self.key_file,
#     365     certfile=self.cert_file,
#     366     key_password=self.key_password,
#     367     ca_certs=self.ca_certs,
#     368     ca_cert_dir=self.ca_cert_dir,
#     369     ca_cert_data=self.ca_cert_data,
#     370     server_hostname=server_hostname,
#     371     ssl_context=context,
#     372 )
#     374 if self.assert_fingerprint:
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/urllib3/connection.py:179, in _new_conn(self)
#     178 self.sock = conn
# --> 179 # Google App Engine's httplib does not define _tunnel_host
#     180 if getattr(self, "_tunnel_host", None):
#     181     # TODO: Fix tunnel so it doesn't depend on self.sock state.
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x14d32d151de0>, 'Connection to cdn-lfs-us-1.hf.co timed out. (connect timeout=10)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/urllib3/connectionpool.py:802, in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/urllib3/util/retry.py:594, in increment(self, method, url, response, error, _pool, _stacktrace)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# MaxRetryError: HTTPSConnectionPool(host='cdn-lfs-us-1.hf.co', port=443): Max retries exceeded with url: /repos/f5/e9/f5e951db06341b22737f6c0853c45e6dc34ffcbc8fad6cd746e46bc7c0ff3553/ab3121e8d66828f8888b456267d5ce7e87063138a04ddde287016df065852277?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27model-00001-of-00003.safetensors%3B+filename%3D%22model-00001-of-00003.safetensors%22%3B&Expires=1728334509&Policy=&Signature=szKVOdcIn8102Whg2DU4~~IaIMZpoK4an86rfjoi5PUbpb5dyPeZGszV6CImBlGlRHfpPK91g4u~f0uK2d7McNU-aZmRepW8tUhO8WekPH8QpEfNU2pwK3OA~xC2eMzWOMHbdFPlGkipde5ELSiBUfMh58oa5a3G0fuA1SoFok1hcsiZqnFmql5MWGdYs194iN6TXIGycQoNUZlGkZ93-iRST0Jon8mrRVp3akJ1IaOaCTZ07C9-F50dJX9EpU~dseJe-Cyn0EAKMxzBj8HJLK8nMQCuegw6~v2eJ9j1w0s-m2ZChBLA4zUokOIzp0NDuLb8eoTvEnU8aFwX8Vvuqw__&Key-Pair-Id=K24J24Z295AEI9 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x14d32d151de0>, 'Connection to cdn-lfs-us-1.hf.co timed out. (connect timeout=10)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[5], line 15
#       1 from transformers import AutoModelForCausalLM, AutoTokenizer
#       2 # device = "cuda" # the device to load the model onto
#       3 # os.environ['CURL_CA_BUNDLE'] = './huggingface.co.crt'
#       4 # export HF_HUB_DOWNLOAD_TIMEOUT=30
#    (...)
#      12 # os.environ['HTTPS_PROXY'] = 'http://127.0.0.1:22'
#      13 # model = AutoModelForCausalLM.from_pretrained("alignment-handbook/zephyr-7b-sft-full", resume_download=True, trust_remote_code=True)
# ---> 15 model = AutoModelForCausalLM.from_pretrained("alignment-handbook/zephyr-7b-sft-full")
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:564, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
# --> 564     return model_class.from_pretrained(
#     565         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566     )
#     567 raise ValueError(
#     568     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     569     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     570 )
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/transformers/modeling_utils.py:3769, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3766 # We'll need to download and cache each checkpoint shard if the checkpoint is sharded.
#    3767 if is_sharded:
#    3768     # resolved_archive_file becomes a list of files that point to the different checkpoint shards in this case.
# -> 3769     resolved_archive_file, sharded_metadata = get_checkpoint_shard_files(
#    3770         pretrained_model_name_or_path,
#    3771         resolved_archive_file,
#    3772         cache_dir=cache_dir,
#    3773         force_download=force_download,
#    3774         proxies=proxies,
#    3775         resume_download=resume_download,
#    3776         local_files_only=local_files_only,
#    3777         token=token,
#    3778         user_agent=user_agent,
#    3779         revision=revision,
#    3780         subfolder=subfolder,
#    3781         _commit_hash=commit_hash,
#    3782     )
#    3784 if (
#    3785     is_safetensors_available()
#    3786     and isinstance(resolved_archive_file, str)
#    3787     and resolved_archive_file.endswith(".safetensors")
#    3788 ):
#    3789     with safe_open(resolved_archive_file, framework="pt") as f:
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/transformers/utils/hub.py:1098, in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, resume_download, local_files_only, token, user_agent, revision, subfolder, _commit_hash, **deprecated_kwargs)
#    1095 for shard_filename in tqdm(shard_filenames, desc="Downloading shards", disable=not show_progress_bar):
#    1096     try:
#    1097         # Load from URL
# -> 1098         cached_filename = cached_file(
#    1099             pretrained_model_name_or_path,
#    1100             shard_filename,
#    1101             cache_dir=cache_dir,
#    1102             force_download=force_download,
#    1103             proxies=proxies,
#    1104             resume_download=resume_download,
#    1105             local_files_only=local_files_only,
#    1106             token=token,
#    1107             user_agent=user_agent,
#    1108             revision=revision,
#    1109             subfolder=subfolder,
#    1110             _commit_hash=_commit_hash,
#    1111         )
#    1112     # We have already dealt with RepositoryNotFoundError and RevisionNotFoundError when getting the index, so
#    1113     # we don't have to catch them here.
#    1114     except EntryNotFoundError:
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/transformers/utils/hub.py:403, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     400 user_agent = http_user_agent(user_agent)
#     401 try:
#     402     # Load from URL or cache if already cached
# --> 403     resolved_file = hf_hub_download(
#     404         path_or_repo_id,
#     405         filename,
#     406         subfolder=None if len(subfolder) == 0 else subfolder,
#     407         repo_type=repo_type,
#     408         revision=revision,
#     409         cache_dir=cache_dir,
#     410         user_agent=user_agent,
#     411         force_download=force_download,
#     412         proxies=proxies,
#     413         resume_download=resume_download,
#     414         token=token,
#     415         local_files_only=local_files_only,
#     416     )
#     417 except GatedRepoError as e:
#     418     resolved_file = _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision)
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/huggingface_hub/utils/_deprecation.py:101, in _deprecate_arguments.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      99         message += "\n\n" + custom_message
#     100     warnings.warn(message, FutureWarning)
# --> 101 return f(*args, **kwargs)
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/huggingface_hub/file_download.py:1232, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, legacy_cache_layout, resume_download, force_filename, local_dir_use_symlinks)
#    1212     return _hf_hub_download_to_local_dir(
#    1213         # Destination
#    1214         local_dir=local_dir,
#    (...)
#    1229         local_files_only=local_files_only,
#    1230     )
#    1231 else:
# -> 1232     return _hf_hub_download_to_cache_dir(
#    1233         # Destination
#    1234         cache_dir=cache_dir,
#    1235         # File info
#    1236         repo_id=repo_id,
#    1237         filename=filename,
#    1238         repo_type=repo_type,
#    1239         revision=revision,
#    1240         # HTTP info
#    1241         endpoint=endpoint,
#    1242         etag_timeout=etag_timeout,
#    1243         headers=headers,
#    1244         proxies=proxies,
#    1245         token=token,
#    1246         # Additional options
#    1247         local_files_only=local_files_only,
#    1248         force_download=force_download,
#    1249     )
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/huggingface_hub/file_download.py:1381, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1379 Path(lock_path).parent.mkdir(parents=True, exist_ok=True)
#    1380 with WeakFileLock(lock_path):
# -> 1381     _download_to_tmp_and_move(
#    1382         incomplete_path=Path(blob_path + ".incomplete"),
#    1383         destination_path=Path(blob_path),
#    1384         url_to_download=url_to_download,
#    1385         proxies=proxies,
#    1386         headers=headers,
#    1387         expected_size=expected_size,
#    1388         filename=filename,
#    1389         force_download=force_download,
#    1390     )
#    1391     if not os.path.exists(pointer_path):
#    1392         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/huggingface_hub/file_download.py:1915, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download)
#    1912         _check_disk_space(expected_size, incomplete_path.parent)
#    1913         _check_disk_space(expected_size, destination_path.parent)
# -> 1915     http_get(
#    1916         url_to_download,
#    1917         f,
#    1918         proxies=proxies,
#    1919         resume_size=resume_size,
#    1920         headers=headers,
#    1921         expected_size=expected_size,
#    1922     )
#    1924 logger.info(f"Download complete. Moving file to {destination_path}")
#    1925 _chmod_and_move(incomplete_path, destination_path)
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/huggingface_hub/file_download.py:455, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     452 if resume_size > 0:
#     453     headers["Range"] = "bytes=%d-" % (resume_size,)
# --> 455 r = _request_wrapper(
#     456     method="GET", url=url, stream=True, proxies=proxies, headers=headers, timeout=constants.HF_HUB_DOWNLOAD_TIMEOUT
#     457 )
#     458 hf_raise_for_status(r)
#     459 content_length = r.headers.get("Content-Length")
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/huggingface_hub/file_download.py:387, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     384     return response
#     386 # Perform request and return if status_code is not in the retry list.
# --> 387 response = get_session().request(method=method, url=url, **params)
#     388 hf_raise_for_status(response)
#     389 return response
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/huggingface_hub/utils/_http.py:93, in UniqueRequestIdAdapter.send(self, request, *args, **kwargs)
#      91 """Catch any RequestException to append request id to the error message for debugging."""
#      92 try:
# ---> 93     return super().send(request, *args, **kwargs)
#      94 except requests.RequestException as e:
#      95     request_id = request.headers.get(X_AMZN_TRACE_ID)
#
# File ~/miniconda3/envs/simpo/lib/python3.10/site-packages/requests/adapters.py:688, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     685 if isinstance(e.reason, ConnectTimeoutError):
#     686     # TODO: Remove this in 3.0.0: see #2811
#     687     if not isinstance(e.reason, NewConnectionError):
# --> 688         raise ConnectTimeout(e, request=request)
#     690 if isinstance(e.reason, ResponseError):
#     691     raise RetryError(e, request=request)
#
# ConnectTimeout: (MaxRetryError("HTTPSConnectionPool(host='cdn-lfs-us-1.hf.co', port=443): Max retries exceeded with url: /repos/f5/e9/f5e951db06341b22737f6c0853c45e6dc34ffcbc8fad6cd746e46bc7c0ff3553/ab3121e8d66828f8888b456267d5ce7e87063138a04ddde287016df065852277?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27model-00001-of-00003.safetensors%3B+filename%3D%22model-00001-of-00003.safetensors%22%3B&Expires=1728334509&Policy=&Signature=szKVOdcIn8102Whg2DU4~~IaIMZpoK4an86rfjoi5PUbpb5dyPeZGszV6CImBlGlRHfpPK91g4u~f0uK2d7McNU-aZmRepW8tUhO8WekPH8QpEfNU2pwK3OA~xC2eMzWOMHbdFPlGkipde5ELSiBUfMh58oa5a3G0fuA1SoFok1hcsiZqnFmql5MWGdYs194iN6TXIGycQoNUZlGkZ93-iRST0Jon8mrRVp3akJ1IaOaCTZ07C9-F50dJX9EpU~dseJe-Cyn0EAKMxzBj8HJLK8nMQCuegw6~v2eJ9j1w0s-m2ZChBLA4zUokOIzp0NDuLb8eoTvEnU8aFwX8Vvuqw__&Key-Pair-Id=K24J24Z295AEI9 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x14d32d151de0>, 'Connection to cdn-lfs-us-1.hf.co timed out. (connect timeout=10)'))"), '(Request ID: 8531a7a0-5c54-43c7-b889-eea460062228)')

# %%
model
# Out:
# GPT2Model(
#   (wte): Embedding(50257, 768)
#   (wpe): Embedding(1024, 768)
#   (drop): Dropout(p=0.1, inplace=False)
#   (h): ModuleList(
#     (0-11): 12 x GPT2Block(
#       (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (attn): GPT2SdpaAttention(
#         (c_attn): Conv1D(nf=2304, nx=768)
#         (c_proj): Conv1D(nf=768, nx=768)
#         (attn_dropout): Dropout(p=0.1, inplace=False)
#         (resid_dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (mlp): GPT2MLP(
#         (c_fc): Conv1D(nf=3072, nx=768)
#         (c_proj): Conv1D(nf=768, nx=3072)
#         (act): NewGELUActivation()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# )

# %%
# !pip install requests==2.27.1
# Out:
# Requirement already satisfied: requests==2.27.1 in /home/hpc/v100dd/v100dd18/miniconda3/envs/simpo/lib/python3.10/site-packages (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/hpc/v100dd/v100dd18/miniconda3/envs/simpo/lib/python3.10/site-packages (from requests==2.27.1) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hpc/v100dd/v100dd18/miniconda3/envs/simpo/lib/python3.10/site-packages (from requests==2.27.1) (2024.8.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/hpc/v100dd/v100dd18/miniconda3/envs/simpo/lib/python3.10/site-packages (from requests==2.27.1) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/hpc/v100dd/v100dd18/miniconda3/envs/simpo/lib/python3.10/site-packages (from requests==2.27.1) (3.8)

# %%
import os
os.environ['CURL_CA_BUNDLE'] = ''

# %%
import urllib3, socket
from urllib3.connection import HTTPConnection

HTTPConnection.default_socket_options = ( 
    HTTPConnection.default_socket_options + [
    (socket.SOL_SOCKET, socket.SO_SNDBUF, 2000000), 
    (socket.SOL_SOCKET, socket.SO_RCVBUF, 2000000)
    ])

# %%
# !pip uninstall requests -y
# Out:
# Found existing installation: requests 2.28.2
# Uninstalling requests-2.28.2:
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/apps/jupyterhub/jh3.1.1-py3.11/lib/python3.11/shutil.py", line 825, in move
#     os.rename(src, real_dst)
# OSError: [Errno 18] Invalid cross-device link: '/apps/jupyterhub/jh3.1.1-py3.11/lib/python3.11/site-packages/requests-2.28.2.dist-info/' -> '/tmp/pip-uninstall-1mckujfq'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/apps/jupyterhub/jh3.1.1-py3.11/lib/python3.11/site-packages/pip/_internal/cli/base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/apps/jupyterhub/jh3.1.1-py3.11/lib/python3.11/site-packages/pip/_internal/commands/uninstall.py", line 105, in run
#     uninstall_pathset = req.uninstall(
#                         ^^^^^^^^^^^^^^
#   File "/apps/jupyterhub/jh3.1.1-py3.11/lib/python3.11/site-packages/pip/_internal/req/req_install.py", line 680, in uninstall
#     uninstalled_pathset.remove(auto_confirm, verbose)
#   File "/apps/jupyterhub/jh3.1.1-py3.11/lib/python3.11/site-packages/pip/_internal/req/req_uninstall.py", line 381, in remove
#     moved.stash(path)
#   File "/apps/jupyterhub/jh3.1.1-py3.11/lib/python3.11/site-packages/pip/_internal/req/req_uninstall.py", line 272, in stash
#     renames(path, new_path)
#   File "/apps/jupyterhub/jh3.1.1-py3.11/lib/python3.11/site-packages/pip/_internal/utils/misc.py", line 313, in renames
#     shutil.move(old, new)
#   File "/apps/jupyterhub/jh3.1.1-py3.11/lib/python3.11/shutil.py", line 843, in move
#     rmtree(src)
#   File "/apps/jupyterhub/jh3.1.1-py3.11/lib/python3.11/shutil.py", line 732, in rmtree
#     _rmtree_safe_fd(fd, path, onerror)
#   File "/apps/jupyterhub/jh3.1.1-py3.11/lib/python3.11/shutil.py", line 683, in _rmtree_safe_fd
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "/apps/jupyterhub/jh3.1.1-py3.11/lib/python3.11/shutil.py", line 681, in _rmtree_safe_fd
#     os.unlink(entry.name, dir_fd=topfd)
# OSError: [Errno 30] Read-only file system: 'top_level.txt'
